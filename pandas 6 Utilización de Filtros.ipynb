# %% [markdown]
# ### Código utilizado en el video:
# https://youtu.be/hUhq7rXRkGw

# %%
import pandas as pd
from datetime import date

# %%
vendedores_df = pd.read_excel('pandas 6 - datos de vendedores.xlsx')

# %%
vendedores_df.head()
# Out:
#      NOMBRE   APELLIDO REGION ASIGNADA FECHA INGRESO  VENTAS  \
# 0   Luciana  Rodríguez          Brasil    2021-08-01   180.0
# 1  Santiago   González         Uruguay    2013-12-03   130.0
# 2     Paola      Gómez        Colombia    2014-11-20   198.0
# 3    Carlos  Fernández          Brasil    2022-03-14   150.0
# 4  Jonathan      López        Paraguay    2018-07-19   135.0
#
#   CALIFICACION DADA POR LOS CLIENTES
# 0                          MUY BUENA
# 1                               MALA
# 2                          MUY BUENA
# 3                               MALA
# 4                               MALA

# %%
vendedores_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   NOMBRE                              42 non-null     object
#  1   APELLIDO                            42 non-null     object
#  2   REGION ASIGNADA                     42 non-null     object
#  3   FECHA INGRESO                       42 non-null     datetime64[ns]
#  4   VENTAS                              42 non-null     float64
#  5   CALIFICACION DADA POR LOS CLIENTES  42 non-null     object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 2.1+ KB

# %%
vendedores_df['VENDEDOR'] = vendedores_df['APELLIDO'] +', '+ vendedores_df['NOMBRE']

# %%
vendedores_df.head()
# Out:
#      NOMBRE   APELLIDO REGION ASIGNADA FECHA INGRESO  VENTAS  \
# 0   Luciana  Rodríguez          Brasil    2021-08-01   180.0
# 1  Santiago   González         Uruguay    2013-12-03   130.0
# 2     Paola      Gómez        Colombia    2014-11-20   198.0
# 3    Carlos  Fernández          Brasil    2022-03-14   150.0
# 4  Jonathan      López        Paraguay    2018-07-19   135.0
#
#   CALIFICACION DADA POR LOS CLIENTES            VENDEDOR
# 0                          MUY BUENA  Rodríguez, Luciana
# 1                               MALA  González, Santiago
# 2                          MUY BUENA        Gómez, Paola
# 3                               MALA   Fernández, Carlos
# 4                               MALA     López, Jonathan

# %%
vendedores_df.drop(['NOMBRE','APELLIDO'], axis=1, inplace=True)
vendedores_df.head()
# Out:
#   REGION ASIGNADA FECHA INGRESO  VENTAS CALIFICACION DADA POR LOS CLIENTES  \
# 0          Brasil    2021-08-01   180.0                          MUY BUENA
# 1         Uruguay    2013-12-03   130.0                               MALA
# 2        Colombia    2014-11-20   198.0                          MUY BUENA
# 3          Brasil    2022-03-14   150.0                               MALA
# 4        Paraguay    2018-07-19   135.0                               MALA
#
#              VENDEDOR
# 0  Rodríguez, Luciana
# 1  González, Santiago
# 2        Gómez, Paola
# 3   Fernández, Carlos
# 4     López, Jonathan

# %%
vendedores_df[vendedores_df['VENTAS'] >= 180]
# Out:
#    REGION ASIGNADA FECHA INGRESO  VENTAS CALIFICACION DADA POR LOS CLIENTES  \
# 0           Brasil    2021-08-01   180.0                          MUY BUENA
# 2         Colombia    2014-11-20   198.0                          MUY BUENA
# 6            Chile    2017-10-06   220.0                          EXCELENTE
# 8          Uruguay    2016-09-03   219.0                          EXCELENTE
# 9        Argentina    2013-04-17   200.0                           EXCLENTE
# 10          Brasil    2018-12-01   195.0                          MUY BUENA
# 11         Ecuador    2018-09-03   190.0                          MUY BUENA
# 12           Chile    2017-09-05   187.0                          MUY BUENA
# 14          Brasil    2022-05-09   180.0                          MUY BUENA
# 19          Brasil    2013-06-27   180.0                          MUY BUENA
# 20       Argentina    2021-05-20   190.0                          MUY BUENA
# ...

# %%
vendedores_df[vendedores_df['VENTAS'] < 180]
# Out:
#    REGION ASIGNADA FECHA INGRESO  VENTAS CALIFICACION DADA POR LOS CLIENTES  \
# 1          Uruguay    2013-12-03   130.0                               MALA
# 3           Brasil    2022-03-14   150.0                               MALA
# 4         Paraguay    2018-07-19   135.0                               MALA
# 5            Chile    2019-10-07   148.0                              BUENA
# 7        Argentina    2015-01-05   155.0                              BUENA
# 13       Argentina    2019-02-03   170.0                              BUENA
# 15         Uruguay    2019-11-10   135.0                               MALA
# 16        Paraguay    2016-12-12   140.0                               MALA
# 17        Colombia    2014-01-13   150.0                              BUENA
# 18         Ecuador    2014-08-25   160.0                              BUENA
# 22          Brasil    2013-12-03   130.0                               MALA
# ...

# %%
vendedores_df[vendedores_df['VENTAS'] < 180]['VENDEDOR']
# Out:
# 1      González, Santiago
# 3       Fernández, Carlos
# 4         López, Jonathan
# 5      Martínez, Gabriela
# 7     Torres, Maximiliano
# 13            Rojas, Luis
# 15        Blanco, Gerardo
# 16        Luna, Guillermo
# 17      Morales, Leonardo
# 18        Navarro, Daniel
# 22       Barrios, Valeria
# 24       Gallardo, Olivia
# 25        Crespo, Candela
# 26     Batistuta, Claudia
# 28     Acevedo, Alejandro
# 34    Bustamante, Esteban
# 36        Guevara, Isabel
# 37           Aquino, Hugo
# 38          Alegre, Lucas
# 39         Prieto, Miguel
# Name: VENDEDOR, dtype: object

# %%
region_br_df = vendedores_df[vendedores_df['REGION ASIGNADA'] == 'Brasil']
region_br_df.head()
# Out:
#    REGION ASIGNADA FECHA INGRESO  VENTAS CALIFICACION DADA POR LOS CLIENTES  \
# 0           Brasil    2021-08-01   180.0                          MUY BUENA
# 3           Brasil    2022-03-14   150.0                               MALA
# 10          Brasil    2018-12-01   195.0                          MUY BUENA
# 14          Brasil    2022-05-09   180.0                          MUY BUENA
# 19          Brasil    2013-06-27   180.0                          MUY BUENA
#
#               VENDEDOR
# 0   Rodríguez, Luciana
# 3    Fernández, Carlos
# 10       Acosta, Carla
# 14     Medina, Alberto
# 19     Vera, Florencia

# %%
region_br_df.shape
# Out:
# (9, 5)

# %%
todo_excepto_br = vendedores_df[vendedores_df['REGION ASIGNADA'] != 'Brasil']
todo_excepto_br.head()
# Out:
#   REGION ASIGNADA FECHA INGRESO  VENTAS CALIFICACION DADA POR LOS CLIENTES  \
# 1         Uruguay    2013-12-03   130.0                               MALA
# 2        Colombia    2014-11-20   198.0                          MUY BUENA
# 4        Paraguay    2018-07-19   135.0                               MALA
# 5           Chile    2019-10-07   148.0                              BUENA
# 6           Chile    2017-10-06   220.0                          EXCELENTE
#
#              VENDEDOR
# 1  González, Santiago
# 2        Gómez, Paola
# 4     López, Jonathan
# 5  Martínez, Gabriela
# 6    Romero, Ezequiel

# %%
todo_excepto_br.shape
# Out:
# (33, 5)

# %%
mejores_br_df = vendedores_df[ (vendedores_df['REGION ASIGNADA'] == 'Brasil') & (vendedores_df['VENTAS'] >= 180)]
mejores_br_df.head()
# Out:
#    REGION ASIGNADA FECHA INGRESO  VENTAS CALIFICACION DADA POR LOS CLIENTES  \
# 0           Brasil    2021-08-01   180.0                          MUY BUENA
# 10          Brasil    2018-12-01   195.0                          MUY BUENA
# 14          Brasil    2022-05-09   180.0                          MUY BUENA
# 19          Brasil    2013-06-27   180.0                          MUY BUENA
# 27          Brasil    2017-10-06   220.0                          EXCELENTE
#
#               VENDEDOR
# 0   Rodríguez, Luciana
# 10       Acosta, Carla
# 14     Medina, Alberto
# 19     Vera, Florencia
# 27     Gallo, Victoria

# %%
fecha_actual = date.today()
print(fecha_actual.year)
# Out:
# 2022

# %%
vendedores_df[vendedores_df['FECHA INGRESO'].apply(lambda x: fecha_actual.year - x.year) > 7]
# Out:
#    REGION ASIGNADA FECHA INGRESO  VENTAS CALIFICACION DADA POR LOS CLIENTES  \
# 1          Uruguay    2013-12-03   130.0                               MALA
# 2         Colombia    2014-11-20   198.0                          MUY BUENA
# 9        Argentina    2013-04-17   200.0                           EXCLENTE
# 17        Colombia    2014-01-13   150.0                              BUENA
# 18         Ecuador    2014-08-25   160.0                              BUENA
# 19          Brasil    2013-06-27   180.0                          MUY BUENA
# 22          Brasil    2013-12-03   130.0                               MALA
# 23         Ecuador    2014-11-20   198.0                          MUY BUENA
# 30           Chile    2013-04-17   200.0                           EXCLENTE
# 38           Chile    2014-01-13   150.0                              BUENA
# 39        Paraguay    2014-08-25   160.0                              BUENA
# ...

# %%
vendedores_df[vendedores_df['FECHA INGRESO'].apply(lambda x: fecha_actual.year - x.year) <= 2]
# Out:
#    REGION ASIGNADA FECHA INGRESO  VENTAS CALIFICACION DADA POR LOS CLIENTES  \
# 0           Brasil    2021-08-01   180.0                          MUY BUENA
# 3           Brasil    2022-03-14   150.0                               MALA
# 14          Brasil    2022-05-09   180.0                          MUY BUENA
# 20       Argentina    2021-05-20   190.0                          MUY BUENA
# 21       Argentina    2021-08-01   180.0                          MUY BUENA
# 24        Paraguay    2022-03-14   150.0                               MALA
# 35          Brasil    2022-05-09   180.0                          MUY BUENA
# 41       Argentina    2021-05-20   190.0                          MUY BUENA
#
#               VENDEDOR
# 0   Rodríguez, Luciana
# 3    Fernández, Carlos
# 14     Medina, Alberto
# 20        Soria, Pablo
# 21       Duarte, Paula
# 24    Gallardo, Olivia
# 35    Pacheco, Cecilia
# 41    Ibarra, Fernando
