# %% [markdown]
# ### Código utilizado en el video:
# https://youtu.be/tGIzX2jcRiA

# %%
import pandas as pd

# %% [markdown]
# # Precios de Bitcoin 2017-2022
# 1- Cantidad total de valores<br>
# 2- Promedio<br>
# 3- Desviación estándar<br>
# 4- Valor mínimo<br>
# 5- 25%<br>
# 6- 50%<br>
# 7- 75%<br>
# 8- Valor máximo<br>

# %%
btc2017_df = pd.read_csv('BTC-USD-2017.csv')
btc2018_df = pd.read_csv('BTC-USD-2018.csv')
btc2019_df = pd.read_csv('BTC-USD-2019.csv')
btc2020_df = pd.read_csv('BTC-USD-2020.csv')
btc2021_df = pd.read_csv('BTC-USD-2021.csv')
btc2022_df = pd.read_csv('BTC-USD-2022.csv')

# %%
btc2017_df.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2017-01-01   963.658020  1003.080017   958.698975   998.325012
# 1  2017-01-02   998.617004  1031.390015   996.702026  1021.750000
# 2  2017-01-03  1021.599976  1044.079956  1021.599976  1043.839966
# 3  2017-01-04  1044.400024  1159.420044  1044.400024  1154.729980
# 4  2017-01-05  1156.729980  1191.099976   910.416992  1013.380005
#
#      Adj Close     Volume
# 0   998.325012  147775008
# 1  1021.750000  222184992
# 2  1043.839966  185168000
# 3  1154.729980  344945984
# 4  1013.380005  510199008

# %%
btc2022_df.tail()
# Out:
#            Date          Open          High           Low         Close  \
# 247  2022-09-05  19988.789063  20031.160156  19673.046875  19812.371094
# 248  2022-09-06  19817.724609  20155.269531  18800.171875  18837.667969
# 249  2022-09-07  18837.683594  19427.171875  18644.466797  19290.324219
# 250  2022-09-08  19289.941406  19417.351563  19076.714844  19329.833984
# 251  2022-09-09  19321.416016  21439.410156  19321.416016  21352.308594
#
#         Adj Close       Volume
# 247  19812.371094  28813460025
# 248  18837.667969  43403978910
# 249  19290.324219  35239757134
# 250  19329.833984  32194477850
# 251  21352.308594  48373846016

# %%
print("Año 2017")
print(btc2017_df.shape)
print("Año 2018")
print(btc2018_df.shape)
print("Año 2019")
print(btc2019_df.shape)
print("Año 2020")
print(btc2020_df.shape)
print("Año 2021")
print(btc2021_df.shape)
print("Año 2022")
print(btc2022_df.shape)
# Out:
# Año 2017
# (365, 7)
# Año 2018
# (365, 7)
# Año 2019
# (365, 7)
# Año 2020
# (366, 7)
# Año 2021
# (365, 7)
# Año 2022
# (252, 7)

# %%
BTCdesde2017a2022_df = pd.concat([btc2017_df, btc2018_df, btc2019_df, btc2020_df, btc2021_df, btc2022_df])

# %%
BTCdesde2017a2022_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2078 entries, 0 to 251
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2078 non-null   object
#  1   Open       2078 non-null   float64
#  2   High       2078 non-null   float64
#  3   Low        2078 non-null   float64
#  4   Close      2078 non-null   float64
#  5   Adj Close  2078 non-null   float64
#  6   Volume     2078 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 129.9+ KB

# %%
BTCdesde2017a2022_df.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2017-01-01   963.658020  1003.080017   958.698975   998.325012
# 1  2017-01-02   998.617004  1031.390015   996.702026  1021.750000
# 2  2017-01-03  1021.599976  1044.079956  1021.599976  1043.839966
# 3  2017-01-04  1044.400024  1159.420044  1044.400024  1154.729980
# 4  2017-01-05  1156.729980  1191.099976   910.416992  1013.380005
#
#      Adj Close     Volume
# 0   998.325012  147775008
# 1  1021.750000  222184992
# 2  1043.839966  185168000
# 3  1154.729980  344945984
# 4  1013.380005  510199008

# %%
BTCdesde2017a2022_df.tail()
# Out:
#            Date          Open          High           Low         Close  \
# 247  2022-09-05  19988.789063  20031.160156  19673.046875  19812.371094
# 248  2022-09-06  19817.724609  20155.269531  18800.171875  18837.667969
# 249  2022-09-07  18837.683594  19427.171875  18644.466797  19290.324219
# 250  2022-09-08  19289.941406  19417.351563  19076.714844  19329.833984
# 251  2022-09-09  19321.416016  21439.410156  19321.416016  21352.308594
#
#         Adj Close       Volume
# 247  19812.371094  28813460025
# 248  18837.667969  43403978910
# 249  19290.324219  35239757134
# 250  19329.833984  32194477850
# 251  21352.308594  48373846016

# %%
BTCdesde2017a2022_df = pd.concat([btc2017_df, btc2018_df, btc2019_df, btc2020_df, btc2021_df, btc2022_df], ignore_index=True)

# %%
BTCdesde2017a2022_df.tail()
# Out:
#             Date          Open          High           Low         Close  \
# 2073  2022-09-05  19988.789063  20031.160156  19673.046875  19812.371094
# 2074  2022-09-06  19817.724609  20155.269531  18800.171875  18837.667969
# 2075  2022-09-07  18837.683594  19427.171875  18644.466797  19290.324219
# 2076  2022-09-08  19289.941406  19417.351563  19076.714844  19329.833984
# 2077  2022-09-09  19321.416016  21439.410156  19321.416016  21352.308594
#
#          Adj Close       Volume
# 2073  19812.371094  28813460025
# 2074  18837.667969  43403978910
# 2075  19290.324219  35239757134
# 2076  19329.833984  32194477850
# 2077  21352.308594  48373846016

# %%
BTCdesde2017a2022_df['Close'].describe()
# Out:
# count     2078.000000
# mean     17575.735006
# std      17183.892855
# min        777.757019
# 25%       6318.507446
# 50%       9342.116211
# 75%      29095.133789
# max      67566.828125
# Name: Close, dtype: float64
